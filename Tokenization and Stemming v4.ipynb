# %%
import pandas as pd
import numpy as np
import json

import random
random.seed(10)  # set the random seed to re-produce the deterministic result

from collections import Counter
import string
from matplotlib import pyplot as plt

import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')

import seaborn as sns
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Selecting a random business b1

# %%
reviewList = []
print("Started Reading JSON file which contains multiple JSON objects")
with open('data/reviewSelected100.json', encoding = "ISO-8859-1") as datafile:
    for jsonObj in datafile:
        reviewDict = json.loads(jsonObj)
        reviewList.append(reviewDict)


print("Selecting a random business b1")
businessidList = []
for review in reviewList:
    businessidList.append(review["business_id"])


random_businessid = random.choice(businessidList)
print(type(random_businessid))
print("Random business b1 selected: "+random_businessid)  # AktuBx1W7c3ZdzwuaOp8xg
# Out:
# Started Reading JSON file which contains multiple JSON objects
# Selecting a random business b1
# <class 'str'>
# Random business b1 selected: AktuBx1W7c3ZdzwuaOp8xg

# %% [markdown]
# ## Extracting all reviews from b1 to form small dataset B1

# %%
B1_list = []
for review in reviewList:
    if review["business_id"] == random_businessid: # considering all reviews for same business b1
        B1_list.append(review["text"])

print(B1_list)  # list of strings with stop words and punctuations
# Out:
# ['Gross!! I tried it cuz I woke across the street but OMG... dry ass food... I wanted to puke!!', 'fantastic, we tried 5 items and they were all excellent. our appetizer was the pot stickers, then we all shared the house special lo mein, the general xaos, the sesame beef, and the chicken wraps. all yummy, cant wait to go again. the woman behind the counter was polite, friendly, and very helpful.', "Not far from the house I really wanted to try LD after seeing a flier.  So I popped in with the GF after seeing a movie thinking we could eat and chat about it..\n\nWith a few missed turn offs we finally located the place as it truly is tucked away and off the beaten path.  After walking in we were greeted but not in a warm and welcoming sort of way but rather in a stoic way.\n\nI ordered up some Pad Thai and the GF ordered the Sesame Chicken.  The came out quickly and we began to eat.  The Pad Thai was fine but i did not really care for my GF's chicken.\n\nI really wanted to like this place but instead I realized that maybe I don't live as close to it as I thought.", "Dumpling is in their name and I didn't try one! Darn it... next time! I did try their Kung Pao Triple lunch special. For $6.25 I got a combination of beef, pork & shrimp along with fried rice and soup. Not bad! It tasted good too. I felt my wife got a bigger portion in her lunch special that was mere .30 less than mine but I had a nice combo of meats. I have eaten at another little Dumpling location across town and have no idea if they are connected but this location is much better. This is a great place for lunch.", 'Came here for late lunch with my husband and son. They served us pretty quick. Our servers were very nice and friendly. The chef also came and greeted us and check to see if we were ok. The food tasted ok. Not horrible at all for the price we paid. Will definitely go back.', 'Fast, friendly, but flavorless. Beef and broccoli was tender but had the flavor of water', 'Disgusting.  Tomatoes in the noodles, even the eggs in soup were rancid.  $30 food straight in the trash.', "I have never been a big fan of Chinese food..but i have to say this wasn't bad...the fried rice was great and my sweet and sour shrimp was good....the crab Rangoon ehhh not so great.... IF i have a craving for Chinese again i will try again", 'I love this place. I had a friend tell me about it 5 years ago. It is a hole in the wall for sure but those are the best and this place hold true to that. They have a similar menu to China a go go but their flavor is so much better. One night I got China a go go and the next night I got little dumpling and there was no comparison. I have ordered from this place countless times and only had 2 times where they messed our order and it wasnt even major, one time I remember they for got 2 egg rolls. Another major plus is they are really fast.', 'We ordered delivery and got the Family Dinner B with shrimp in lobster sauce, pepper beef, bbq pork fried rice, steamed rice and it came with 2 egg rolls, 2 crab rangoons, 2 fried shrimp and wonton soup for $26.95 which I thought was a good deal. The food was good, not excellent. Not a lot of shrimp in the shrimp & lobster sauce, mostly on top rather than mixed in. The crab rangoons were very good and we received 4 free. My only major complaint would be that the wonton soup has entirely too much cabbage in it. I would say half of the container was just chunks of cabbage. Other than that delivery was relatively quick and it was good enough to order from again.', "This is my go to spot for Chinese takeout. The Thai is slightly above average. Avoid the teriyaki as it's pretty plain. Prices are cheap and the staff is friendly. Too bad it's smack dab in the middle of my commute. Here's a tip though, their delivery radius is much wider than you probably think. Call them and ask if they can deliver and you might be surprised. \n\nDishes that stand out:\n\nWalnut shrimp (I don't see it on the menu for some reason, but ...

# %% [markdown]
# ## Pre-processing of dataset B1
# #### Tokenizing after removal of punctuations and stopwords

# %%
# combine list of strings in B1_list to a single string and incaptitalized words
B1_string = ''.join(B1_list).lower()
#print(B1_string)

## remove all punctuation marks from string
B1_string_nopunc = B1_string.translate(str.maketrans('', '', string.punctuation))
#print(B1_string_nopunc)

## tokenize string B1_string_nopunc
word_tokens = word_tokenize(B1_string_nopunc)
# print(word_tokens)

## remove stop words from tokenized list of words without punctuation
stop_words = set(stopwords.words('english'))
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

# print(type(filtered_sentence))

# %% [markdown]
# ## Show word frequency and top 10 words distribution before stemming

# %%
# count the frequency of each word and put in a dictionary with word (key), frequency (value)
count = Counter(filtered_sentence)

print(count.most_common(10)) # list word and frequency for top 10 words in a dictionary
print(count) # list word and frequency for all words in a dictionary

count = dict(count)
# Plot bar Graph
word_freq = pd.DataFrame(count.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
word_freq["frequency"] = np.log10(word_freq["frequency"])


# create plot of the different data frames
sns.set(rc={'figure.figsize':(35,30)})
b = sns.barplot(x='frequency',y='word',data=word_freq.head(200))
b.get_figure().savefig("images/b1_before_stem.png")
# Out:
# [('food', 116), ('chicken', 75), ('good', 68), ('place', 63), ('order', 62), ('chinese', 60), ('little', 49), ('shrimp', 41), ('like', 40), ('rice', 37)]
# Counter({'food': 116, 'chicken': 75, 'good': 68, 'place': 63, 'order': 62, 'chinese': 60, 'little': 49, 'shrimp': 41, 'like': 40, 'rice': 37, 'fried': 34, 'beef': 33, 'go': 33, 'ordered': 33, 'soup': 33, 'thai': 32, 'lunch': 30, 'great': 28, 'would': 27, 'service': 26, 'restaurant': 26, 'dumpling': 25, 'back': 25, 'get': 25, 'also': 24, 'sour': 24, 'really': 23, 'time': 23, 'well': 23, 'see': 22, 'sauce': 22, 'try': 21, 'delivery': 21, 'pad': 20, 'one': 20, 'egg': 20, 'dont': 19, 'got': 19, 'even': 19, '2': 19, 'hot': 18, 'ive': 18, 'take': 18, 'better': 17, 'takeout': 17, 'spicy': 17, 'new': 17, 'always': 17, 'wait': 16, 'friendly': 16, 'crab': 16, 'years': 16, 'menu': 16, 'im': 16, 'took': 16, 'special': 15, 'eat': 15, 'family': 15, 'around': 15, '5': 14, 'came': 14, 'didnt': 14, 'pork': 14, 'sweet': 14, 'minutes': 14, 'first': 14, 'way': 13, 'close': 13, 'nice': 13, 'much': 13, 'us': 13, 'price': 13, 'noodles': 13, 'places': 13, 'dumplings': 13, 'mein': 12, 'tasted': 12, 'ago': 12, 'best': 12, 'rolls': 12, 'favorite': 12, 'quality': 12, 'nothing': 12, 'everything': 12, 'went': 12, 'decided': 12, 'delicious': 12, 'lo': 11, 'kung': 11, 'pretty': 11, 'lot': 11, 'dishes': 11, 'know': 11, 'orange': 11, 'cooked': 11, 'looking': 11, 'small': 11, 'henderson': 11, 'restaurants': 11, 'give': 11, 'ever': 11, 'meat': 11, 'away': 10, 'never': 10, 'say': 10, 'love': 10, '4': 10, 'enough': 10, 'cheap': 10, 'staff': 10, 'many': 10, 'portions': 10, 'full': 10, 'last': 10, 'fast': 10, 'almost': 10, 'specials': 10, 'right': 10, '3': 10, 'ewe': 10, 'tried': 9, 'items': 9, 'excellent': 9, 'cant': 9, 'could': 9, 'bad': 9, 'definitely': 9, 'wasnt': 9, 'night': 9, 'wonton': 9, 'prices': 9, 'think': 9, 'still': 9, 'used': 9, 'reviews': 9, 'found': 9, 'comes': 9, 'bit': 9, 'said': 9, 'isnt': 9, 'side': 9, 'owners': 9, 'taste': 9, 'thing': 9, 'ordering': 9, 'lemon': 9, 'next': 8, 'pao': 8, 'another': 8, 'flavor': 8, 'big': 8, 'sure': 8, 'times': 8, 'free': 8, 'probably': 8, 'find': 8, 'left': 8, 'come': 8, 'made': 8, 'worth': 8, 'business': 8, 'phone': 8, 'asked': 8, 'going': 8, 'meal': 8, 'ill': 8, 'called': 8, 'wontons': 8, 'area': 8, 'moved': 8, 'dish': 8, 'veggies': 8, 'plates': 8, 'wanted': 7, 'yummy': 7, 'counter': 7, 'location': 7, 'ok': 7, 'broccoli': 7, 'rangoon': 7, 'surprised': 7, 'mongolian': 7, 'fresh': 7, 'tasty': 7, 'kind': 7, 'happy': 7, 'plate': 7, 'super': 7, 'usually': 7, 'make': 7, 'pick': 7, 'since': 7, 'chewy': 7, 'long': 7, 'every': 7, 'dine': 7, 'greasy': 7, 'veggie': 7, 'experience': 7, 'tea': 7, 'sesame': 6, 'quickly': 6, 'maybe': 6, 'live': 6, '30': 6, 'less': 6, 'quick': 6, 'pepper': 6, 'rangoons': 6, 'deal': 6, 'teriyaki': 6, 'walnut': 6, 'large': 6, 'pineapple': 6, 'perfectly': 6, 'home': 6, 'delivered': 6, 'glad': 6, 'people': 6, 'star': 6, 'pay': 6, 'online': 6, 'want': 6, 'easy': 6, 'day': 6, 'end': 6, 'mind': 6, 'vegetable': 6, 'crispy': 6, 'amazing': 6, 'something': 6, 'things': 6, 'actually': 6, 'money': 6, 'ready': 6, 'enjoyed': 6, 'several': 6, 'waiting': 6, 'review': 6, 'thats': 6, 'however': 6, 'without': 6, 'let': 6, 'kitchen': 6, 'considering': 6, 'starbucks': 6, 'walgreens': 6, 'amount': 6, 'across': 5, 'general': 5, 'behind': 5, 'finally': 5, 'rather': 5, 'fine': 5, 'wife': 5, 'town': 5, 'idea': 5, 'husband': 5, 'served': 5, 'check': 5, 'paid': 5, 'craving': 5, 'plus': 5, 'bbq': 5, 'spot': 5, 'though': 5, 'ask': 5, 'visit': 5, 'customer': 5, 'honey': 5, 'low': 5, 'simple': 5, 'two': 5, 'tofu': 5, '10': 5, '6': 5, 'serve': 5, 'salt': 5, 'huge': 5, 'plenty': 5, 'yum': 5, 'added': 5, '15': 5, 'later': 5, 'gave': 5, 'clean': 5, 'orders': 5, '1': 5, 'leftovers': 5, 'lady': 5, 'doesnt': 5, 'wont': 5, 'driver': 5, 'youre': 5, 'worst': 5, 'dining': 5, 'ones': 5, 'wrong': 5, 'hour': 5, 'least': 5, 'options': 5, 'bland': 5, 'cup': 5, 'plastic': 5, 'type': 5, 'street': 4, 'pot': 4, 'house': 4, 'woman': 4, 'far': 4, 'tucked': 4, 'instead': 4, 'flavorless': 4, 'china': 4, 'dinner': 4, 'steamed': 4, 'thought': 4, 'mostly ...

# %% [markdown]
# ## Stemming algorithm

# %%
ps = PorterStemmer()

stemmed_list = []

for words_to_stem in filtered_sentence:
    stemmed_list.append(ps.stem(words_to_stem))

print(stemmed_list)
# Out:
# ['gross', 'tri', 'cuz', 'woke', 'across', 'street', 'omg', 'dri', 'ass', 'food', 'want', 'pukefantast', 'tri', '5', 'item', 'excel', 'appet', 'pot', 'sticker', 'share', 'hous', 'special', 'lo', 'mein', 'gener', 'xao', 'sesam', 'beef', 'chicken', 'wrap', 'yummi', 'cant', 'wait', 'go', 'woman', 'behind', 'counter', 'polit', 'friendli', 'helpfulnot', 'far', 'hous', 'realli', 'want', 'tri', 'ld', 'see', 'flier', 'pop', 'gf', 'see', 'movi', 'think', 'could', 'eat', 'chat', 'miss', 'turn', 'off', 'final', 'locat', 'place', 'truli', 'tuck', 'away', 'beaten', 'path', 'walk', 'greet', 'warm', 'welcom', 'sort', 'way', 'rather', 'stoic', 'way', 'order', 'pad', 'thai', 'gf', 'order', 'sesam', 'chicken', 'came', 'quickli', 'began', 'eat', 'pad', 'thai', 'fine', 'realli', 'care', 'gf', 'chicken', 'realli', 'want', 'like', 'place', 'instead', 'realiz', 'mayb', 'dont', 'live', 'close', 'thoughtdumpl', 'name', 'didnt', 'tri', 'one', 'darn', 'next', 'time', 'tri', 'kung', 'pao', 'tripl', 'lunch', 'special', '625', 'got', 'combin', 'beef', 'pork', 'shrimp', 'along', 'fri', 'rice', 'soup', 'bad', 'tast', 'good', 'felt', 'wife', 'got', 'bigger', 'portion', 'lunch', 'special', 'mere', '30', 'less', 'mine', 'nice', 'combo', 'meat', 'eaten', 'anoth', 'littl', 'dumpl', 'locat', 'across', 'town', 'idea', 'connect', 'locat', 'much', 'better', 'great', 'place', 'lunchcam', 'late', 'lunch', 'husband', 'son', 'serv', 'us', 'pretti', 'quick', 'server', 'nice', 'friendli', 'chef', 'also', 'came', 'greet', 'us', 'check', 'see', 'ok', 'food', 'tast', 'ok', 'horribl', 'price', 'paid', 'definit', 'go', 'backfast', 'friendli', 'flavorless', 'beef', 'broccoli', 'tender', 'flavor', 'waterdisgust', 'tomato', 'noodl', 'even', 'egg', 'soup', 'rancid', '30', 'food', 'straight', 'trashi', 'never', 'big', 'fan', 'chines', 'foodbut', 'say', 'wasnt', 'badth', 'fri', 'rice', 'great', 'sweet', 'sour', 'shrimp', 'goodth', 'crab', 'rangoon', 'ehhh', 'great', 'crave', 'chines', 'tri', 'againi', 'love', 'place', 'friend', 'tell', '5', 'year', 'ago', 'hole', 'wall', 'sure', 'best', 'place', 'hold', 'true', 'similar', 'menu', 'china', 'go', 'go', 'flavor', 'much', 'better', 'one', 'night', 'got', 'china', 'go', 'go', 'next', 'night', 'got', 'littl', 'dumpl', 'comparison', 'order', 'place', 'countless', 'time', '2', 'time', 'mess', 'order', 'wasnt', 'even', 'major', 'one', 'time', 'rememb', 'got', '2', 'egg', 'roll', 'anoth', 'major', 'plu', 'realli', 'fastw', 'order', 'deliveri', 'got', 'famili', 'dinner', 'b', 'shrimp', 'lobster', 'sauc', 'pepper', 'beef', 'bbq', 'pork', 'fri', 'rice', 'steam', 'rice', 'came', '2', 'egg', 'roll', '2', 'crab', 'rangoon', '2', 'fri', 'shrimp', 'wonton', 'soup', '2695', 'thought', 'good', 'deal', 'food', 'good', 'excel', 'lot', 'shrimp', 'shrimp', 'lobster', 'sauc', 'mostli', 'top', 'rather', 'mix', 'crab', 'rangoon', 'good', 'receiv', '4', 'free', 'major', 'complaint', 'would', 'wonton', 'soup', 'entir', 'much', 'cabbag', 'would', 'say', 'half', 'contain', 'chunk', 'cabbag', 'deliveri', 'rel', 'quick', 'good', 'enough', 'order', 'againthi', 'go', 'spot', 'chines', 'takeout', 'thai', 'slightli', 'averag', 'avoid', 'teriyaki', 'pretti', 'plain', 'price', 'cheap', 'staff', 'friendli', 'bad', 'smack', 'dab', 'middl', 'commut', 'here', 'tip', 'though', 'deliveri', 'radiu', 'much', 'wider', 'probabl', 'think', 'call', 'ask', 'deliv', 'might', 'surpris', 'dish', 'stand', 'walnut', 'shrimp', 'dont', 'see', 'menu', 'reason', 'order', 'often', 'enough', 'know', 'exist', '9', '20', 'larg', 'shrimp', 'pork', 'hot', 'garlic', 'sauc', 'singapor', 'noodl', 'bbq', 'pork', 'fri', 'ricethi', 'awesom', 'find', 'came', 'crave', 'chines', 'left', 'want', 'open', 'locat', 'reno', 'staff', 'beyond', 'friendli', 'food', 'entic', 'come', 'back', 'mongolian', 'beef', 'well', 'balanc', 'still', 'crisp', 'wellcook', 'onion', 'gener', 'chicken', 'pineappl', 'balanc', 'heat', 'orang', 'chicken', 'perfectli', 'cook', 'well', 'sauc', 'pineappl', 'fri', 'rice', 'fresh', 'tasti', ' ...

# %% [markdown]
# ## Show word frequency and top 10 words distribution after stemming

# %%
## count the frequeuncy of each word and put in a dictionary with word (key), frequency (value)
stemmed_count = Counter(stemmed_list)
print(stemmed_count.most_common(10)) # list word and frequency for top 10 words in a dictionary
#print(count) # list word and frequency for all words in a dictionary 

stemmed_count = dict(stemmed_count)
## Plot bar Graph


word_freq = pd.DataFrame(stemmed_count.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
word_freq["frequency"] = np.log10(word_freq["frequency"])

## create plot of the different data frames
sns.set(rc={'figure.figsize':(35,30)})
a = sns.barplot(x='frequency',y='word',data=word_freq.head(200))
a.get_figure().savefig("images/b1_after_stem.png")
# Out:
# [('food', 119), ('order', 110), ('place', 78), ('chicken', 75), ('good', 68), ('chines', 60), ('littl', 49), ('like', 46), ('shrimp', 42), ('go', 41)]

# %% [markdown]
# # ---------------------------- end of business b1 ----------------------------

# %% [markdown]
# # Repeat process for another randomly selected business b2

# %% [markdown]
# ## Selecting a random business b2

# %%
reviewList = []
print("Started Reading JSON file which contains multiple JSON objects")
with open('data/reviewSelected100.json', encoding = "ISO-8859-1") as datafile:
    for jsonObj in datafile:
        new_reviewDict = json.loads(jsonObj)
        reviewList.append(new_reviewDict)


print("Selecting a random business b2")
businessidList = []
for review in reviewList:
    businessidList.append(review["business_id"])


random_businessid = random.choice(businessidList)
print(type(random_businessid))
print("Random business b2 selected: "+random_businessid)
# Out:
# Started Reading JSON file which contains multiple JSON objects
# Selecting a random business b2
# <class 'str'>
# Random business b2 selected: e-YnECeZNt8ngm0tu4X9mQ

# %% [markdown]
# ## Extracting all reviews from b2 to form small dataset B2

# %%
B2_list = []
for review in reviewList:
    if review["business_id"] == random_businessid: # considering all reviews for same business b2
        B2_list.append(review["text"])

#print(B2_list)  # list of strings with stop words and punctuations

# %% [markdown]
# ## Pre-processing of dataset B2
# #### Tokenizing after removal of punctuations and stopwords

# %%
# combine list of strings in B1_list to a single string
B2_string = ''.join(B2_list).lower()
#print(B1_string)

## remove all punctuation marks from string
B2_string_nopunc = B2_string.translate(str.maketrans('', '', string.punctuation))
#print(B1_string_nopunc)

## tokenize string B1_string_nopunc
word_tokens = word_tokenize(B2_string_nopunc)

## remove stop words from tokenized list of words without punctuation
stop_words = set(stopwords.words('english'))
filtered_sentence_B2 = [q for q in word_tokens if not q.lower() in stop_words]

print(filtered_sentence_B2)
# Out:
# ['good', 'korean', 'grill', 'near', 'eaton', 'centre', 'marinate', 'good', 'got', 'beef', 'ox', 'liver', 'salmon', 'fish', 'fillet', 'chicken', 'pork', 'pork', 'belly', 'fish', 'fillet', 'bland', 'liver', 'meh', 'salmon', 'chicken', 'really', 'flavourable', 'fun', 'place', 'eat', 'date', 'group', 'friends', 'even', 'alone', 'judgments', 'staff', 'attentive', 'nice', 'considerate', 'bigger', 'groups', 'likely', 'seated', 'second', 'floor', 'way', 'bigger', 'caution', 'smell', 'like', 'bbq', 'grill', 'aftergood', 'foodwell', 'cook', 'great', 'place', 'good', 'location', 'decent', 'price', 'would', 'rated', 'higher', 'service', 'betterbeen', 'times', 'n', 'wait', 'n', 'call', 'get', 'food', 'drinks', 'servers', 'always', 'interested', 'look', 'gets', 'matter', 'polite', 'try', 'bei', 'dont', 'think', 'ive', 'ever', 'disappointed', 'korean', 'bbq', 'establishment', 'place', 'first', 'servers', 'took', 'forever', 'come', 'take', 'orders', 'thought', 'bit', 'ridiculous', 'one', 'us', 'wanted', 'order', 'veggies', 'order', 'well', 'secondly', 'grill', 'friend', 'sharing', 'wasnt', 'working', 'properly', 'took', 'half', 'hour', 'come', 'fixreplace', 'oh', 'wanted', 'order', 'side', 'dishes', 'drinks', 'literally', 'wave', 'yell', 'server', 'come', 'table', 'food', 'subpar', 'veggies', 'dry', 'wilted', 'fish', 'smelled', 'bit', 'funny', 'meats', 'overly', 'seasoned', 'top', 'route', 'bathroom', 'consisted', 'passing', 'meat', 'literally', 'sitting', 'buckets', 'blood', 'grossed', 'pretty', 'bad', 'experience', 'say', 'least', 'dont', 'think', 'ill', 'going', 'ps', 'dont', 'cash', 'credit', 'dont', 'even', 'think', 'going', 'placegreat', 'lunch', 'price', '11', 'tax', 'tip', 'onto', 'food', 'ayce', 'normal', 'menu', 'squid', 'white', 'fish', 'fillet', 'shaved', 'pork', 'shaved', 'beef', 'spicy', 'chicken', 'side', 'dishes', 'included', 'fried', 'tofu', 'spicy', 'kimchi', 'spicy', 'normal', 'bean', 'sprout', 'pickled', 'radish', 'beef', 'soup', 'rice', 'considering', 'lunch', 'menu', 'offering', 'isnt', 'bad', 'earns', '3', 'stars', 'shined', 'service', 'might', 'odd', 'staff', 'member', 'took', 'pride', 'great', 'service', 'found', 'attentive', 'kept', 'table', 'well', 'stocked', 'side', 'dishes', 'pounding', 'meat', 'dumping', 'grill', 'change', 'grill', 'quick', 'courteous', 'note', 'offer', 'ayce', 'veggiepineapple', 'addition', 'get', '3', 'dollars', 'going', 'strictly', 'costfood', 'ratio', 'isnt', 'recommended', 'would', 'definitely', 'return', 'however', 'considering', 'hard', 'ayce', 'healthy', 'living', 'aspect', 'life', 'unfortunately', 'splurge', '3', 'stars', 'food', 'price', '1', 'star', 'servicereally', 'bad', 'service', 'remind', 'servers', 'least', '3', 'times', 'get', 'ordered', 'ordered', 'taro', 'bubble', 'tea', 'ended', 'getting', 'purple', 'ice', 'water', 'old', 'tapioca', 'half', 'hour', 'later', 'wait', 'long', 'rice', 'come', 'meat', 'gets', 'cold', 'terrible', 'go', 'againkorean', 'grill', 'house', 'located', 'yonge', 'gerrard', 'gould', 'east', 'side', 'located', 'upper', 'level', 'building', 'confusing', 'idea', 'whats', 'bottom', 'ive', 'always', 'taken', 'upstairs', 'came', 'weeks', 'ago', 'coworker', 'pretty', 'pleased', 'food', 'price', 'ordered', 'takeout', 'back', 'office', 'beef', 'bibm', 'bahb', '950', 'tax', 'ready', 'went', 'pick', 'coworker', 'dish', 'shared', 'previous', 'time', 'knew', 'would', 'good', 'note', 'took', 'forever', 'answer', 'phone', 'hang', 'guy', 'phone', 'took', 'order', 'wasnt', 'personable', 'unfortunately', 'small', 'part', 'disappointment', 'come', 'get', 'back', 'office', 'open', 'container', 'looks', 'good', 'rice', 'kimchee', 'beef', 'together', 'topped', 'fried', 'egg', 'hot', 'sauce', 'side', 'went', 'mixing', 'hot', 'sauce', 'got', 'eating', 'first', 'thing', 'found', 'short', 'black', 'hair', 'since', 'hair', 'super', 'long', 'light', 'brown', 'definitely', 'mine', 'unfortunate', 'great', 'point', 'best', 'cordon', 'side', 'dish', 'continue', 'eat', 'since', 'bites', 't ...

# %% [markdown]
# ## Show word frequency and top 10 words distribution before stemming

# %%
## count the frequeuncy of each word and put in a dictionary with word (key), frequency (value)
count = Counter(filtered_sentence_B2)
print(count.most_common(10)) # list word and frequency for top 10 words in a dictionary
#print(count) # list word and frequency for all words in a dictionary 

count = dict(count)

## Plot bar Graph


word_freq = pd.DataFrame(count.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
word_freq["frequency"] = np.log10(word_freq["frequency"])


## create plot of the different data frames
sns.set(rc={'figure.figsize':(35,30)})
c = sns.barplot(x='frequency',y='word',data=word_freq.head(200))
c.get_figure().savefig("images/b2_before_stem.png")
# Out:
# [('food', 99), ('korean', 93), ('meat', 84), ('grill', 76), ('place', 71), ('service', 67), ('good', 65), ('bbq', 64), ('eat', 52), ('get', 50)]

# %% [markdown]
# ## Stemming algorithm

# %%
ps = PorterStemmer()

stemmed_list = []

for words_to_stem in filtered_sentence_B2:
    stemmed_list.append(ps.stem(words_to_stem))

print(stemmed_list)
# Out:
# ['good', 'korean', 'grill', 'near', 'eaton', 'centr', 'marin', 'good', 'got', 'beef', 'ox', 'liver', 'salmon', 'fish', 'fillet', 'chicken', 'pork', 'pork', 'belli', 'fish', 'fillet', 'bland', 'liver', 'meh', 'salmon', 'chicken', 'realli', 'flavour', 'fun', 'place', 'eat', 'date', 'group', 'friend', 'even', 'alon', 'judgment', 'staff', 'attent', 'nice', 'consider', 'bigger', 'group', 'like', 'seat', 'second', 'floor', 'way', 'bigger', 'caution', 'smell', 'like', 'bbq', 'grill', 'aftergood', 'foodwel', 'cook', 'great', 'place', 'good', 'locat', 'decent', 'price', 'would', 'rate', 'higher', 'servic', 'betterbeen', 'time', 'n', 'wait', 'n', 'call', 'get', 'food', 'drink', 'server', 'alway', 'interest', 'look', 'get', 'matter', 'polit', 'tri', 'bei', 'dont', 'think', 'ive', 'ever', 'disappoint', 'korean', 'bbq', 'establish', 'place', 'first', 'server', 'took', 'forev', 'come', 'take', 'order', 'thought', 'bit', 'ridicul', 'one', 'us', 'want', 'order', 'veggi', 'order', 'well', 'secondli', 'grill', 'friend', 'share', 'wasnt', 'work', 'properli', 'took', 'half', 'hour', 'come', 'fixreplac', 'oh', 'want', 'order', 'side', 'dish', 'drink', 'liter', 'wave', 'yell', 'server', 'come', 'tabl', 'food', 'subpar', 'veggi', 'dri', 'wilt', 'fish', 'smell', 'bit', 'funni', 'meat', 'overli', 'season', 'top', 'rout', 'bathroom', 'consist', 'pass', 'meat', 'liter', 'sit', 'bucket', 'blood', 'gross', 'pretti', 'bad', 'experi', 'say', 'least', 'dont', 'think', 'ill', 'go', 'ps', 'dont', 'cash', 'credit', 'dont', 'even', 'think', 'go', 'placegreat', 'lunch', 'price', '11', 'tax', 'tip', 'onto', 'food', 'ayc', 'normal', 'menu', 'squid', 'white', 'fish', 'fillet', 'shave', 'pork', 'shave', 'beef', 'spici', 'chicken', 'side', 'dish', 'includ', 'fri', 'tofu', 'spici', 'kimchi', 'spici', 'normal', 'bean', 'sprout', 'pickl', 'radish', 'beef', 'soup', 'rice', 'consid', 'lunch', 'menu', 'offer', 'isnt', 'bad', 'earn', '3', 'star', 'shine', 'servic', 'might', 'odd', 'staff', 'member', 'took', 'pride', 'great', 'servic', 'found', 'attent', 'kept', 'tabl', 'well', 'stock', 'side', 'dish', 'pound', 'meat', 'dump', 'grill', 'chang', 'grill', 'quick', 'courteou', 'note', 'offer', 'ayc', 'veggiepineappl', 'addit', 'get', '3', 'dollar', 'go', 'strictli', 'costfood', 'ratio', 'isnt', 'recommend', 'would', 'definit', 'return', 'howev', 'consid', 'hard', 'ayc', 'healthi', 'live', 'aspect', 'life', 'unfortun', 'splurg', '3', 'star', 'food', 'price', '1', 'star', 'servicer', 'bad', 'servic', 'remind', 'server', 'least', '3', 'time', 'get', 'order', 'order', 'taro', 'bubbl', 'tea', 'end', 'get', 'purpl', 'ice', 'water', 'old', 'tapioca', 'half', 'hour', 'later', 'wait', 'long', 'rice', 'come', 'meat', 'get', 'cold', 'terribl', 'go', 'againkorean', 'grill', 'hous', 'locat', 'yong', 'gerrard', 'gould', 'east', 'side', 'locat', 'upper', 'level', 'build', 'confus', 'idea', 'what', 'bottom', 'ive', 'alway', 'taken', 'upstair', 'came', 'week', 'ago', 'cowork', 'pretti', 'pleas', 'food', 'price', 'order', 'takeout', 'back', 'offic', 'beef', 'bibm', 'bahb', '950', 'tax', 'readi', 'went', 'pick', 'cowork', 'dish', 'share', 'previou', 'time', 'knew', 'would', 'good', 'note', 'took', 'forev', 'answer', 'phone', 'hang', 'guy', 'phone', 'took', 'order', 'wasnt', 'person', 'unfortun', 'small', 'part', 'disappoint', 'come', 'get', 'back', 'offic', 'open', 'contain', 'look', 'good', 'rice', 'kimche', 'beef', 'togeth', 'top', 'fri', 'egg', 'hot', 'sauc', 'side', 'went', 'mix', 'hot', 'sauc', 'got', 'eat', 'first', 'thing', 'found', 'short', 'black', 'hair', 'sinc', 'hair', 'super', 'long', 'light', 'brown', 'definit', 'mine', 'unfortun', 'great', 'point', 'best', 'cordon', 'side', 'dish', 'continu', 'eat', 'sinc', 'bite', 'that', 'one', 'star', 'gone', 'right', 'thought', 'tast', 'would', 'still', 'prevail', 'crunch', 'someth', 'hard', 'cant', 'bite', 'spit', 'mouth', 'get', 'look', 'seem', 'piec', 'ceram', 'eerili', 'similar', 'bowl', 'typic', 'mix', 'server', 'bibm', 'bahb', 'big', 'huge ...

# %% [markdown]
# ## Show word frequency and top 10 words distribution after stemming

# %%
## count the frequeuncy of each word and put in a dictionary with word (key), frequency (value)
stemmed_count = Counter(stemmed_list)
print(stemmed_count.most_common(10)) # list word and frequency for top 10 words in a dictionary
#print(count) # list word and frequency for all words in a dictionary 

stemmed_count = dict(stemmed_count)

## Plot bar Graph


word_freq = pd.DataFrame(stemmed_count.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
word_freq["frequency"] = np.log10(word_freq["frequency"])


## create plot of the different data frames
sns.set(rc={'figure.figsize':(35,30)})
d = sns.barplot(x='frequency',y='word',data=word_freq.head(200))
d.get_figure().savefig("images/b2_after_stem.png")
# Out:
# [('meat', 104), ('food', 99), ('grill', 96), ('korean', 94), ('place', 88), ('servic', 68), ('good', 66), ('bbq', 65), ('get', 61), ('eat', 59)]

# %% [markdown]
# # ---------------------------- end of business b2 ----------------------------
